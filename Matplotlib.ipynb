# %% [markdown]
# <a href="https://colab.research.google.com/github/dreamer561/DataScience/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# To Plot data

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# plt.plot(x,y)
plt.plot(y,x)

# %%
plt.plot(x,y,'y')
plt.xlabel('x Axis title Here')
plt.ylabel('y Axis title Here')
# Out:
# Text(0, 0.5, 'y Axis title Here')

# %%
plt.title('String Title Here')
# Out:
# Text(0.5, 1.0, 'String Title Here')

# %%
#Creating multiple plots on same Canvas
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'b*-')

# %%
#Create figure(Empty Canvas)
fig=plt.figure()
#add set of axes
axes=fig.add_axes([0.1,0.1,0.8,0.8])

#plot on the set of axes
axes.plot(x,y,'g')
axes.set_xlabel('Set X label')
axes.set_ylabel('Set Y label')
axes.set_title('Set title')
# Out:
# Text(0.5, 1.0, 'Set title')

# %% [markdown]
# ####Lacture 15

# %%
#Nested Plot
#blank canvas 
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.2,0.4,0.3])
#Larger axes axex(1)
axes1.plot(x,y,'b')
axes1.set_xlabel('x label set')
axes1.set_ylabel('y label set')
axes1.set_title('Axes 1 title')

#Smaller axes axex(1)
axes2.plot(y,x,'r')
axes2.set_xlabel('x label set')
axes2.set_ylabel('y label set')
axes2.set_title('Axes 2 title')
# Out:
# Text(0.5, 1.0, 'Axes 2 title')

# %%
#Subplots
fig,axes=plt.subplots()
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
#subplots with multiple axes Set
fig,axes=plt.subplots(nrows=1,ncols=2)
for ax in axes:
  ax.plot(x,y,'g')
  ax.set_xlabel('x')
  ax.set_ylabel('y')
  ax.set_title('title')

# %% [markdown]
# Lacture 16

# %% [markdown]
# Figure size ,aspect ratio and DPI

# %%
fig=plt.figure(figsize=(8,4),dpi=100)
fig

# %%
fig=plt.figure()

# %%
# from matplotlib.figure import Figure
fig, axes=plt.subplots(figsize=(12,4))
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('this is title')
# Out:
# Text(0.5, 1.0, 'this is title')

# %% [markdown]
# #Saving Graphs

# %%
fig.savefig('xtoyGraph.png')

# %%
fig.savefig('xtoyGraphdpi.png',dpi=200)

# %% [markdown]
# Lacture 17

# %% [markdown]
# Legends Labels and Titles

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="x**2")
ax.plot(x,x**3,label="x**3")
ax.legend()
ax.legend(loc=1)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="x**2")
ax.plot(x,x**3,label="x**3")

ax.legend(loc=4)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="x**2")
ax.plot(x,x**3,label="x**3")
ax.legend()
ax.legend(loc=3)

# %% [markdown]
# ##Colors With Matplotlib Graphs##

# %%
fig ,ax=plt.subplots()
ax.plot(x,x**2,'r')
ax.plot(x,x**3,'g')
# ax.show()

# %%
fig,ax=plt.subplots()
ax.plot(x,x+1,color='blue')
ax.plot(x,x+2,color='#000000')
ax.plot(x,x+3,color='#FF8C00')

# %%
#Width of line
fig , ax=plt.subplots(figsize=(12,6))
ax.plot(x,x+1,'r',linewidth=0.25)
ax.plot(x,x+2,'b',linewidth=0.50)
ax.plot(x,x+3,'g',linewidth=1.0)
ax.plot(x,x+4,'y',linewidth=2.0)
ax.plot(x,x+5,'r',lw=3.50,linestyle='-.')
ax.plot(x,x+6,'black',lw=4.50,linestyle=':')
